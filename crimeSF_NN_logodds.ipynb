# %% [markdown]
# # San Francisco Crime prediction
# # Based on 2 layer neural net and count featurizer

# %%
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.cross_validation import train_test_split
from sklearn.grid_search import GridSearchCV
import matplotlib.pylab as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn import preprocessing
from sklearn.metrics import log_loss
from sklearn.metrics import make_scorer
from sklearn.cross_validation import StratifiedShuffleSplit
from matplotlib.colors import LogNorm
from sklearn.decomposition import PCA
from keras.layers.advanced_activations import PReLU
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.normalization import BatchNormalization
from keras.models import Sequential
from keras.utils import np_utils
from copy import deepcopy
# %matplotlib inline
# Out:
# Using Theano backend.

# %% [markdown]
# Import data

# %%
trainDF=pd.read_csv("train.csv")

# %% [markdown]
# Clean up wrong X and Y values (very few of them)

# %%
xy_scaler=preprocessing.StandardScaler()
xy_scaler.fit(trainDF[["X","Y"]])
trainDF[["X","Y"]]=xy_scaler.transform(trainDF[["X","Y"]])
trainDF=trainDF[abs(trainDF["Y"])<100]
trainDF.index=range(len(trainDF))
plt.plot(trainDF["X"],trainDF["Y"],'.')
plt.show()

# %% [markdown]
# Make plots for each crime label

# %%
NX=100
NY=100
groups = trainDF.groupby('Category')
ii=1
plt.figure(figsize=(20, 20))
for name, group in groups:
    plt.subplot(8,5,ii)
    histo, xedges, yedges = np.histogram2d(np.array(group.X),np.array(group.Y), bins=(NX,NY))
    myextent  =[xedges[0],xedges[-1],yedges[0],yedges[-1]]
    plt.imshow(histo.T,origin='low',extent=myextent,interpolation='nearest',aspect='auto',norm=LogNorm())
    plt.title(name)
#     plt.figure(ii)
#     plt.plot(group.X,group.Y,'.')
    ii+=1
del groups

# %%
# Out:
# ARSON
#                       Dates Category                        Descript  \
# 661     2015-05-12 01:46:00    ARSON              ARSON OF A VEHICLE
# 1076    2015-05-11 05:00:00    ARSON                           ARSON
# 1802    2015-05-02 05:39:00    ARSON                           ARSON
# 1917    2015-05-01 21:15:00    ARSON                 ATTEMPTED ARSON
# 1933    2015-05-01 20:00:00    ARSON                           ARSON
# 3052    2015-04-29 06:35:00    ARSON              ARSON OF A VEHICLE
# 3096    2015-04-29 01:05:00    ARSON                           ARSON
# 3449    2015-04-28 01:25:00    ARSON              ARSON OF A VEHICLE
# 4637    2015-04-18 09:09:00    ARSON                           ARSON
# 4877    2015-04-17 18:30:00    ARSON        FIRE, UNLAWFULLY CAUSING
# 5557    2015-04-16 01:13:00    ARSON              ARSON OF A VEHICLE
# 5570    2015-04-16 00:30:00    ARSON  ARSON OF AN INHABITED DWELLING
# 6265    2015-04-14 13:00:00    ARSON  ARSON OF AN INHABITED DWELLING
# 6871    2015-04-05 20:00:00    ARSON              ARSON OF A VEHICLE
# 7104    2015-04-05 04:42:00    ARSON                           ARSON
# 7202    2015-04-04 22:50:00    ARSON                           ARSON
# 7576    2015-04-04 00:30:00    ARSON                           ARSON
# 8065    2015-04-02 23:00:00    ARSON                           ARSON
# 8202    2015-04-02 18:10:00    ARSON                           ARSON
# 8897    2015-03-31 21:00:00    ARSON                           ARSON
# 9641    2015-03-30 04:45:00    ARSON        FIRE, UNLAWFULLY CAUSING
# 10888   2015-03-20 06:30:00    ARSON                           ARSON
# 11756   2015-03-18 01:39:00    ARSON  ARSON OF A COMMERCIAL BUILDING
# 3052    Wednesday    RICHMOND             NONE
# 3096    Wednesday     CENTRAL             NONE
# 3449      Tuesday    SOUTHERN             NONE
# 4637     Saturday    NORTHERN             NONE
# 4877       Friday    SOUTHERN             NONE
# 5557     Thursday   INGLESIDE             NONE
# 5570     Thursday        PARK             NONE
# 6265      Tuesday     TARAVAL             NONE
# 6871       Sunday    SOUTHERN             NONE
# 7104       Sunday     CENTRAL             NONE
# 7202     Saturday    NORTHERN             NONE
# 7576     Saturday     CENTRAL   ARREST, BOOKED
# 8065     Thursday    NORTHERN             NONE
# 8202     Thursday    SOUTHERN   ARREST, BOOKED
# 8897      Tuesday    SOUTHERN             NONE
# 9641       Monday     MISSION   ARREST, BOOKED
# 10888      Friday    NORTHERN             NONE
# 11756   Wednesday     CENTRAL             NONE
# 12584      Monday     BAYVIEW             NONE
# 12621      Monday     MISSION   ARREST, BOOKED
# 13413    Saturday    RICHMOND   ARREST, BOOKED
# 13433    Saturday     BAYVIEW             NONE
# 13912      Friday    SOUTHERN             NONE
# 13996    Thursday     MISSION             NONE
# 14839   Wednesday    NORTHERN             NONE
# ...           ...         ...              ...
# 862413    Tuesday   INGLESIDE             NONE
# 862540    Tuesday     BAYVIEW             NONE
# 862873     Monday    RICHMOND             NONE
# 863186     Monday    RICHMOND             NONE
# 863337     Sunday     MISSION   ARREST, BOOKED
# 864878   Thursday   INGLESIDE             NONE
# 864921  Wednesday   INGLESIDE             NONE
# 865120  Wednesday        PARK             NONE
# 865840     Monday     MISSION             NONE
# 866147     Monday     TARAVAL             NONE
# 867386     Friday   INGLESIDE             NONE
# 868247  Wednesday     BAYVIEW             NONE
# 868248  Wednesday     BAYVIEW             NONE
# 868383    Tuesday    NORTHERN             NONE
# 869683   Saturday     MISSION             NONE
# 869723   Saturday     BAYVIEW             NONE
# 870351     Friday     MISSION             NONE
# 870835   Thursday     TARAVAL             NONE
# 870921  Wednesday   INGLESIDE             NONE
# 870969  Wednesday     BAYVIEW             NONE
# 871708    Tuesday   INGLESIDE             NONE
# 872645   Saturday     CENTRAL             NONE
# 872933   Saturday     BAYVIEW             NONE
# 873416     Friday     BAYVIEW             NONE
# 875104     Monday     BAYVIEW             NONE
# 875291     Sunday    RICHMOND   ARREST, BOOKED
# 875463   Saturday   INGLESIDE  JUVENILE BOOKED
# 875464   Saturday   INGLESIDE  JUVENILE BOOKED
# 876204     Friday     BAYVIEW             NONE
# 876661  Wednesday     MISSION             NONE
#
#                                       Address         X         Y
# 661                    1400 Block of SELBY ST  0.707135 -0.071477
# 1076                   200 Block of FOLSOM ST  0.997206  0.039484
# 1802                     200 Block of 11TH AV -1.557977  0.027569
# 1917               200 Block of MCALLISTER ST  0.198944  0.021000
# 1933                  1800 Block of MARKET ST -0.036193  0.001665
# 3052                     700 Block of 23RD AV -1.962459  0.005602
# 3096                   1200 Block of UNION ST  0.099586  0.061646
# 3449                 1100 Block of MISSION ST  0.362076  0.016567
# 4637              2900 Block of DIVISADERO ST -0.646992  0.056239
# 4877                        0 Block of 6TH ST  0.448225  0.022136
# 5557                 2400 Block of ALEMANY BL -0.745850 -0.121042
# 5570                100 Block of PARNASSUS AV -0.917979 -0.013789
# 6265                  0 Block of CHUMASERO DR -1.655797 -0.126293
# 6871                   800 Block of BRYANT ST  0.632929  0.009631
# 7104             1900 Block of LEAVENWORTH ST  0.170874  0.061624
# 7202                 1700 Block of FILBERT ST -0.187459  0.061270
# 7576                    600 Block of UNION ST  0.425954  0.064141
# 8065                 2400 Block of FILBERT ST -0.565908  0.057829
# 8202                    0 Block of SHERMAN ST  0.549920  0.012216
# 8897               MCCOPPIN ST / STEVENSON ST  0.028582  0.001360
# 9641                 1000 Block of POTRERO AV  0.529668 -0.031810
# 10888                    BAY ST / BUCHANAN ST -0.353033  0.070116
# 11756                  300 Block of SUTTER ST  0.541439  0.040395
# 12584           1200 Block of PENNSYLVANIA AV  0.988114 -0.042264
# 12621                600 Block of VALENCIA ST  0.033168 -0.018097
# 13413                    1100 Block of 9TH AV -1.445889 -0.010547
# 13433                     CRISP RD / PALOU AV  1.404157 -0.094623
# 13912                  800 Block of BRYANT ST  0.632929  0.009631
# 13996               300 Block of SANCARLOS ST  0.091709 -0.029007
# 14839             1700 Block of SACRAMENTO ST  0.029512  0.044703
# ...                                       ...       ...       ...
# 862413               400 Block of BOSWORTH ST -0.294991 -0.082976
# 862540                  RANKIN ST / CUSTER AV  1.039704 -0.053965
# 862873  MARTIN LUTHER KING JR DR / LINCOLN WY -2.859072 -0.015300
# 863186                 3900 Block of GEARY BL -1.284978  0.022411
# 863337               1000 Block of POTRERO AV  0.529668 -0.031810
# 864878                 100 Block of CUVIER ST -0.195177 -0.083420
# 864921         200 Block of JOHN F SHELLEY DR -0.018248 -0.105883
# 865120                    200 Block of NOE ST -0.346964 -0.012158
# 865840                300 Block of POTRERO AV  0.496532 -0.012916
# 866147                  2200 Block of 29TH AV -2.110165 -0.056172
# 867386                 0 Block of CORTLAND AV  0.045248 -0.066932
# 868247               1100 Block of CARROLL AV  1.241707 -0.111058
# 868248               1100 Block of CARROLL AV  1.241707 -0.111058
# 868383                 1000 Block of GOUGH ST -0.050027  0.026124
# 869683              2500 Block of MARIPOSA ST  0.455004 -0.017184
# 869723              1400 Block of BANCROFT AV  1.073013 -0.102961
# 870351               2000 Block of MISSION ST  0.097455 -0.014883
# 870835                  100 Block of LOBOS ST -1.152044 -0.122911
# 870921                600 Block of PRECITA AV  0.443620 -0.050820
# 870969                   0 Block of SIERRA ST  0.889226 -0.027669
# 871708                   30TH ST / MISSION ST  0.021267 -0.062695
# 872645                WASHINGTON ST / HYDE ST  0.154051  0.049599
# 872933              1300 Block of YOSEMITE AV  1.169711 -0.102667
# 873416             2000 Block of BAY SHORE BL  0.773800 -0.123636
# 875104                100 Block of CAMERON WY  1.167401 -0.109552
# 875291                  2400 Block of POST ST -0.645033  0.028527
# 875463               600 Block of PRENTISS ST  0.334410 -0.078316
# 875464               600 Block of PRENTISS ST  0.334410 -0.078316
# 876204              1000 Block of GRIFFITH ST  1.439555 -0.092819
# 876661                  23RD ST / SHOTWELL ST  0.240316 -0.037177
# 877964                                            BATTERY     Monday
# 877968                                            BATTERY     Monday
# 877973                        INFLICT INJURY ON COHABITEE     Monday
# 877975                      ATTEMPTED HOMICIDE WITH A GUN     Monday
#
#         PdDistrict       Resolution                             Address  \
# 17       INGLESIDE             NONE              GODEUS ST / MISSION ST
# 51         BAYVIEW             NONE              23RD ST / WISCONSIN ST
# 109        BAYVIEW             NONE             0 Block of WHITFIELD CT
# 114        CENTRAL             NONE           1400 Block of STOCKTON ST
# 165           PARK             NONE         1700 Block of MCALLISTER ST
# 170        BAYVIEW             NONE        1200 Block of CONNECTICUT ST
# 200      INGLESIDE   ARREST, BOOKED               29TH ST / SAN JOSE AV
# 204     TENDERLOIN             NONE         0 Block of UNITEDNATIONS PZ
# 212        CENTRAL  JUVENILE BOOKED                 300 Block of BAY ST
# 228       SOUTHERN             NONE             500 Block of MISSION ST
# 235        BAYVIEW   ARREST, BOOKED            700 Block of KIRKWOOD AV
# 239        BAYVIEW   ARREST, BOOKED            700 Block of KIRKWOOD AV
# 243      INGLESIDE   ARREST, BOOKED            1500 Block of DOLORES ST
# 265        CENTRAL             NONE              1200 Block of UNION ST
# 268        MISSION   ARREST, BOOKED                800 Block of CAPP ST
# 272      INGLESIDE             NONE             CRESCENT AV / FOLSOM ST
# 296        MISSION             NONE                 24TH ST / FOLSOM ST
# 298        MISSION             NONE                   23RD ST / UTAH ST
# 299        MISSION             NONE                   23RD ST / UTAH ST
# 315       NORTHERN   ARREST, BOOKED                 GROVE ST / GOUGH ST
# 327       SOUTHERN             NONE             1500 Block of MARKET ST
# 357       RICHMOND             NONE                300 Block of 11TH AV
# 358       RICHMOND             NONE                300 Block of 11TH AV
# 403      INGLESIDE             NONE             0 Block of BROOKDALE AV
# 417       SOUTHERN             NONE                  7TH ST / MARKET ST
# 436       SOUTHERN             NONE  0 Block of THE EMBARCADERONORTH ST
# 440        CENTRAL             NONE               700 Block of GEARY ST
# 441        CENTRAL             NONE               700 Block of GEARY ST
# 458      INGLESIDE             NONE            4100 Block of MISSION ST
# 473        BAYVIEW             NONE        1000 Block of CONNECTICUT ST
# ...            ...              ...                                 ...
# 877656     MISSION   ARREST, BOOKED             2400 Block of MARKET ST
# 877658     BAYVIEW   ARREST, BOOKED               1800 Block of 25TH ST
# 877659     BAYVIEW   ARREST, BOOKED               1800 Block of 25TH ST
# 877672     BAYVIEW             NONE                0 Block of HARBOR RD
# 877684     BAYVIEW             NONE                    3RD ST / 18TH ST
# 877718    NORTHERN             NONE               SUTTER ST / LARKIN ST
# 877725     MISSION             NONE            1000 Block of POTRERO AV
# 877735     TARAVAL   ARREST, BOOKED            3900 Block of ALEMANY BL
# 877738     TARAVAL   ARREST, BOOKED            3900 Block of ALEMANY BL
# 877762     TARAVAL             NONE            100 Block of GONZALEZ DR
# 877771     BAYVIEW             NONE             600 Block of DE HARO ST
# 877777    NORTHERN        UNFOUNDED            2200 Block of JACKSON ST
# 877786     MISSION   ARREST, BOOKED                 24TH ST / BRYANT ST
# 877806  TENDERLOIN   ARREST, BOOKED                  TURK ST / JONES ST
# 877815   INGLESIDE             NONE          100 Block of CAPISTRANO AV
# 877824     BAYVIEW             NONE               100 Block of KISKA RD
# 877831    RICHMOND             NONE            800 Block of LA PLAYA ST
# 877835        PARK             NONE              1400 Block of GROVE ST
# 877839   INGLESIDE             NONE    5300 Block of DIAMOND HEIGHTS BL
# 877854     BAYVIEW             NONE               500 Block of TEXAS ST
# 877880    RICHMOND             NONE              POST ST / BRODERICK ST
# 877889     TARAVAL             NONE               100 Block of APTOS AV
# 877904     TARAVAL             NONE               200 Block of BROAD ST
# 877936     CENTRAL             NONE             300 Block of FILBERT ST
# 877937    NORTHERN             NONE              1100 Block of GOUGH ST
# 877961    SOUTHERN             NONE                  6TH ST / MARKET ST
# 877964     BAYVIEW             NONE                 3RD ST / NEWCOMB AV
# 877968    NORTHERN             NONE            1300 Block of WEBSTER ST
# 877973     MISSION             NONE             2800 Block of FOLSOM ST
# 877975     BAYVIEW   ARREST, BOOKED            1500 Block of SHAFTER AV
#
#                X         Y
# 17      0.030801 -0.061717
# 51      0.788073 -0.035620
# 109     1.343449 -0.087364
# 114     0.447556  0.061793
# 165    -0.601677  0.014253
# 170     0.867974 -0.045017
# 200    -0.001836 -0.059263
# 204     0.273397  0.019532
# 212     0.323280  0.076065
# 228     0.760078  0.037446
# 235     1.601033 -0.091525
# 239     1.601033 -0.091525
# 243    -0.057037 -0.056851
# 265     0.078862  0.061231
# 268     0.168580 -0.039256
# 272     0.294083 -0.079427
# 296     0.280937 -0.040524
# 298     0.565358 -0.036515
# 299     0.565358 -0.036515
# 315    -0.018183  0.014873
# 327     0.097179  0.008015
# 357    -1.553350  0.023404
# 358    -1.553350  0.023404
# 403     0.057730 -0.128740
# 417     0.332781  0.020699
# 436     1.127925  0.026899
# 440     0.229357  0.033809
# 441     0.229357  0.033809
# 458    -0.230562 -0.089191
# 473     0.837282 -0.038270
# ...          ...       ...
# 877656 -0.433470 -0.018738
# 877658  0.827549 -0.040959
# 877659  0.827549 -0.040959
# 877672  1.456967 -0.084679
# 877684  1.115992 -0.017444
# 877718  0.136679  0.037087
# 877725  0.529668 -0.031810
# 877735 -1.488264 -0.130657
# 877738 -1.488264 -0.130657
# 877762 -1.742874 -0.114833
# 877771  0.705832 -0.020524
# 877777 -0.312996  0.047749
# 877786  0.444248 -0.039885
# 877806  0.336111  0.026228
# 877815 -0.484925 -0.093013
# 877824  1.536137 -0.089436
# 877831 -2.875407  0.002830
# 877835 -0.589338  0.010158
# 877839 -0.457584 -0.062150
# 877854  0.904416 -0.025822
# 877880 -0.617170  0.028638
# 877889 -1.454244 -0.091566
# 877904 -1.258987 -0.126516
# 877936  0.574738  0.067403
# 877937 -0.064067  0.029213
# 877961  0.405979  0.024536
# 877964  1.060813 -0.077540
# 877968 -0.277724  0.026285
# 877973  0.281454 -0.042320
# 877975  1.082160 -0.088547
#
# [76872 rows x 9 columns]
# BAD CHECKS
#                       Dates    Category  \
# 11207   2015-03-19 14:45:00  BAD CHECKS
# 11531   2015-03-18 17:02:00  BAD CHECKS
HECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday    RICHMOND
# 11531   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday     MISSION
# 20256   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday   INGLESIDE
# 21381   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday     MISSION
# 30023        CHECKS, NON-SUFFICIENT FUNDS (FELONY)     Monday    NORTHERN
# 33953   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday     MISSION
# 41096        CHECKS, NON-SUFFICIENT FUNDS (FELONY)    Tuesday    SOUTHERN
# 44478   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday     BAYVIEW
# 48706   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday     CENTRAL
# 48836   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday     CENTRAL
# 67091   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday     MISSION
# 74895   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday     MISSION
# 78726        CHECKS, NON-SUFFICIENT FUNDS (FELONY)    Tuesday    NORTHERN
# 79099   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday     CENTRAL
# 84088   CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday    SOUTHERN
# 101451  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday    NORTHERN
# 113644  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday     TARAVAL
# 133829  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)    Tuesday    SOUTHERN
# 141430  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday   INGLESIDE
# 143398  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday     TARAVAL
# 151035  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday     BAYVIEW
# 154653  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday     TARAVAL
# 160551       CHECKS, NON-SUFFICIENT FUNDS (FELONY)     Monday     CENTRAL
# 162380       CHECKS, NON-SUFFICIENT FUNDS (FELONY)   Thursday        PARK
# 165124       CHECKS, NON-SUFFICIENT FUNDS (FELONY)   Thursday     BAYVIEW
# 172084  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday    NORTHERN
# 176591  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday    RICHMOND
# 177119  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday    NORTHERN
# 179644  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday     BAYVIEW
# 188280  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)    Tuesday        PARK
# ...                                            ...        ...         ...
# 843008  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday     MISSION
# 844603       CHECKS, NON-SUFFICIENT FUNDS (FELONY)   Thursday     BAYVIEW
# 844780  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday    NORTHERN
# 845338  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)    Tuesday     BAYVIEW
# 845990  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Sunday  TENDERLOIN
# 846958  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday     CENTRAL
# 847590  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday   INGLESIDE
# 847710  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday    SOUTHERN
# 847963  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)    Tuesday    SOUTHERN
# 849718  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday    RICHMOND
# 850163  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday    SOUTHERN
# 851894  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Sunday    NORTHERN
# 853512  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday     CENTRAL
# 857106       CHECKS, NON-SUFFICIENT FUNDS (FELONY)     Monday    RICHMOND
# 857302  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday  TENDERLOIN
# 858005  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Saturday    SOUTHERN
# 858927       CHECKS, NON-SUFFICIENT FUNDS (FELONY)   Thursday     CENTRAL
# 858968  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday    NORTHERN
# 858969  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday    SOUTHERN
# 859807  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)    Tuesday  TENDERLOIN
# 860040       CHECKS, NON-SUFFICIENT FUNDS (FELONY)    Tuesday     MISSION
# 861578  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday        PARK
# 865222  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)  Wednesday    NORTHERN
# 865510       CHECKS, NON-SUFFICIENT FUNDS (FELONY)    Tuesday     CENTRAL
# 872084       CHECKS, NON-SUFFICIENT FUNDS (FELONY)     Monday        PARK
# 873589  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday     CENTRAL
# 876210  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Friday    NORTHERN
# 876508  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday     CENTRAL
# 876525  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)   Thursday     CENTRAL
# 877892  CHECKS, NON-SUFFICIENT FUNDS (MISDEMEANOR)     Monday   INGLESIDE
#
#                               Resolution                         Address  \
# 11207                               NONE     3500 Block of SACRAMENTO ST
# 11531                               NONE        2000 Block of MISSION ST
# 20256                               NONE        400 Block of TERESITA BL
# 21381                               NONE            16TH ST / MISSION ST
# 30023                               NONE     500 Block of GOLDEN GATE AV
# 33953                               NONE         2300 Block of MARKET ST
# 41096                               NONE              0 Block of MINT ST
# 44478                               NONE            4400 Block of 3RD ST
# 48706                               NONE           300 Block of GEARY ST
# 48836                               NONE        0 Block of CALIFORNIA ST
# 67091                               NONE         2300 Block of MARKET ST
# 74895                               NONE            16TH ST / MISSION ST
# 78726                               NONE     1800 Block of WASHINGTON ST
# 79099                               NONE          400 Block of POWELL ST
# 84088                               NONE             100 Block of 8TH ST
# 101451                              NONE        GOLDEN GATE AV / POLK ST
# 113644                              NONE        500 Block of VICTORIA ST
# 133829                              NONE        1100 Block of MISSION ST
# 141430                              NONE     0 Block of SGTJOHNVYOUNG LN
# 143398                              NONE       1100 Block of MONTEREY BL
# 151035                              NONE            4600 Block of 3RD ST
# 154653                              NONE        1100 Block of TARAVAL ST
# 160551                    ARREST, BOOKED      300 Block of CALIFORNIA ST
# 162380                              NONE          1900 Block of ELLIS ST
# 165124                              NONE      3000 Block of SAN BRUNO AV
# 172084                              NONE         800 Block of VANNESS AV
# 176591                         UNFOUNDED              0 Block of 15TH AV
# 177119                              NONE          2600 Block of BAKER ST
# 179644                              NONE        2600 Block of INGALLS ST
# 188280                              NONE         1500 Block of WALLER ST
# ...                                  ...                             ...
# 843008                              NONE         800 Block of POTRERO AV
# 844603                              NONE          100 Block of APOLLO ST
# 844780                              NONE          1900 Block of UNION ST
# 845338                              NONE    700 Block of CESAR CHAVEZ ST
# 845990                              NONE        100 Block of OFARRELL ST
# 846958                              NONE        0 Block of CALIFORNIA ST
# 847590                    ARREST, BOOKED         900 Block of PORTOLA DR
# 847710                    ARREST, BOOKED  100 Block of SOUTH VAN NESS AV
# 847963                              NONE         1000 Block of MARKET ST
# 849718                              NONE     3000 Block of CALIFORNIA ST
# 850163                              NONE          600 Block of BRYANT ST
# 851894      PROSECUTED BY OUTSIDE AGENCY          1600 Block of UNION ST
# 853512      PROSECUTED BY OUTSIDE AGENCY          500 Block of SUTTER ST
# 857106      PROSECUTED BY OUTSIDE AGENCY            600 Block of 25TH AV
# 857302                              NONE            0 Block of POWELL ST
# 858005                              NONE          800 Block of BRYANT ST
# 858927                              NONE      300 Block of SACRAMENTO ST
# 858968                              NONE         3200 Block of PIERCE ST
# 858969      PROSECUTED BY OUTSIDE AGENCY         1100 Block of MARKET ST
# 859807                              NONE             0 Block of GRANT AV
# 860040                              NONE         1600 Block of BRYANT ST
# 861578                              NONE     1800 Block of MCALLISTER ST
# 865222      PROSECUTED BY OUTSIDE AGENCY        400 Block of VAN NESS AV
# 865510  COMPLAINANT REFUSES TO PROSECUTE         300 Block of BATTERY ST
# 872084                              NONE    1400 Block of GOLDEN GATE AV
# 19736      MISSION                    ARREST, BOOKED
# 20433      BAYVIEW                    ARREST, BOOKED
# 23375      MISSION                    ARREST, BOOKED
# 31978     SOUTHERN                              NONE
# 32049      MISSION                    ARREST, BOOKED
# 33278      BAYVIEW                              NONE
# 36888      MISSION                    ARREST, BOOKED
# 38722      MISSION                    ARREST, BOOKED
# 39363   TENDERLOIN                    ARREST, BOOKED
# 40675     SOUTHERN                         UNFOUNDED
# 47800    INGLESIDE                              NONE
# 50763    INGLESIDE                              NONE
# 54870      MISSION                              NONE
# 55705     NORTHERN                    ARREST, BOOKED
# 59460      TARAVAL                              NONE
# 62885     NORTHERN                    ARREST, BOOKED
# 66651    INGLESIDE                    ARREST, BOOKED
# 68988      BAYVIEW                              NONE
# ...            ...                               ...
# ...
# 506             4100 Block of MISSION ST -0.236717 -0.088945
# 508             4100 Block of MISSION ST -0.236717 -0.088945
# 515                 0 Block of TURNER TR  0.906303 -0.031495
# 525               800 Block of BRYANT ST  0.632929  0.009631
# 558             2000 Block of MISSION ST  0.097455 -0.014883
# ...                                  ...       ...       ...
# 877506              0 Block of MABREY CT  1.221545 -0.077054
# 877511           700 Block of BRANNAN ST  0.684780  0.006992
# 877516                 POLK ST / POST ST  0.088502  0.034594
# 877517               5TH ST / SHIPLEY ST  0.651445  0.019280
# 877540  CYRIL MAGNIN STORTH ST / EDDY ST  0.465215  0.029397
# 877542           OFARRELL ST / LARKIN ST  0.155253  0.030963
# 877547        DIVISADERO ST / LOMBARD ST -0.659995  0.061237
# 877560            900 Block of MARKET ST  0.430914  0.025544
# 877589            REVERE AV / INGALLS ST  1.253857 -0.093093
# 877592                 BUSH ST / HYDE ST  0.184398  0.039592
# 877605            800 Block of BRYANT ST  0.632929  0.009631
# 877606            800 Block of BRYANT ST  0.632929  0.009631
# 877614                GEARY ST / POLK ST  0.094770  0.032551
# 877623               SUTTER ST / POLK ST  0.082235  0.036632
# 877640       1100 Block of MCALLISTER ST -0.287510  0.016899
# 877657            300 Block of SAWYER ST  0.277247 -0.125262
# 877730            0 Block of OFARRELL ST  0.550876  0.034393
# 877745              JONES ST / MARKET ST  0.350435  0.021632
# 877749          1500 Block of LOMBARD ST -0.144262  0.065338
# 877789        400 Block of CALIFORNIA ST  0.667135  0.047771
# 877805                TURK ST / JONES ST  0.336111  0.026228
# 877856              15TH ST / VERMONT ST  0.588526 -0.008238
# 877857              15TH ST / VERMONT ST  0.588526 -0.008238
# 877869              4700 Block of 3RD ST  1.060393 -0.078495
# 877874           DIVISADERO ST / PAGE ST -0.481628  0.002591
# 877901      0 Block of UNITED NATIONS PZ  0.273397  0.019532
# 877928             3000 Block of 16TH ST  0.031424 -0.013448
# 877959            NEWHALL ST / GALVEZ AV  1.150000 -0.066419
# 877960            900 Block of MARKET ST  0.425255  0.025843
# 877971              TAYLOR ST / GEARY ST  0.365612  0.034845
#
# [42206 rows x 9 columns]
# WEAPON LAWS
#                       Dates     Category  \
# 38      2015-05-13 20:29:00  WEAPON LAWS
# 82      2015-05-13 18:42:00  WEAPON LAWS
# 877702  2003-01-06 18:11:00  WEAPON LAWS
# 877837  2003-01-06 11:35:00  WEAPON LAWS
# 877843  2003-01-06 11:20:00  WEAPON LAWS
#
#                                                  Descript  DayOfWeek  \
# 38                                     SUSPICIOUS PACKAGE  Wednesday
# 82         EXHIBITING DEADLY WEAPON IN A THREATING MANNER  Wednesday
# 363            DISCHARGE FIREARM AT AN INHABITED DWELLING    Tuesday
# 717        EXHIBITING DEADLY WEAPON IN A THREATING MANNER     Monday
# 745                                POSS OF LOADED FIREARM     Monday
# 746        EXHIBITING DEADLY WEAPON IN A THREATING MANNER     Monday
# 792       POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN     Monday
# 793                                POSS OF LOADED FIREARM     Monday
# 796        FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE     Monday
# 809                           CARRYING A CONCEALED WEAPON     Monday
# 810                                POSS OF LOADED FIREARM     Monday
# 847                           CARRYING A CONCEALED WEAPON     Monday
# 1013               AMMUNITION, POSS. BY PROHIBITED PERSON     Monday
# 1094                            POSS OF PROHIBITED WEAPON     Monday
# 1121                 DISCHARGE FIREARM WITHIN CITY LIMITS     Sunday
# 1180      POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN     Sunday
# 1183    FIREARM, CARRYING LOADED WITH INTENT TO COMMIT...     Sunday
# 1277      POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN     Sunday
# 1620       EXHIBITING DEADLY WEAPON IN A THREATING MANNER   Saturday
# 1627       FIREARM, LOADED, IN VEHICLE, POSSESSION OR USE   Saturday
# 1628                               POSS OF LOADED FIREARM   Saturday
# 1630                 DISCHARGE FIREARM WITHIN CITY LIMITS   Saturday
# 1645       EXHIBITING DEADLY WEAPON IN A THREATING MANNER   Saturday
# 1772                              POSS OF TEAR GAS WEAPON   Saturday
# 1919            FLAMMABLE OR EXPLOSIVE DEVICE, POSSESSION     Friday
# 2019          WEAPON, DEADLY, EXHIBITING TO RESIST ARREST     Friday
# 2146                                POSSESSION OF AIR GUN     Friday
# 2363                            POSS OF PROHIBITED WEAPON   Thursday
# 2547                                POSSESSION OF AIR GUN   Thursday
# 2572      CARRYING OF CONCEALED WEAPON BY CONVICTED FELON   Thursday
# ...                                                   ...        ...
# 874865     EXHIBITING DEADLY WEAPON IN A THREATING MANNER     Monday
# 874881                        CARRYING A CONCEALED WEAPON     Monday
# 874888                             POSS OF LOADED FIREARM     Monday
# 875000                           LOCATED EXPLOSIVE DEVICE     Monday
# 875071    POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN     Monday
# 875077         DISCHARGE FIREARM AT AN INHABITED DWELLING     Monday
# 875096                        CARRYING A CONCEALED WEAPON     Monday
# 875447         DISCHARGE FIREARM AT AN INHABITED DWELLING     Sunday
# 875526                             POSS OF LOADED FIREARM   Saturday
# 875594     EXHIBITING DEADLY WEAPON IN A THREATING MANNER   Saturday
# 875892         DISCHARGE FIREARM AT AN INHABITED DWELLING     Friday
# 875901     EXHIBITING DEADLY WEAPON IN A THREATING MANNER     Friday
# 875957          LOITERING WHILE CARRYING CONCEALED WEAPON     Friday
# 876117     EXHIBITING DEADLY WEAPON IN A THREATING MANNER     Friday
# 876197               DISCHARGE FIREARM WITHIN CITY LIMITS     Friday
# 876369                        CARRYING A CONCEALED WEAPON   Thursday
# 876399         DISCHARGE FIREARM AT AN INHABITED DWELLING   Thursday
# 876421    CARRYING OF CONCEALED WEAPON BY CONVICTED FELON   Thursday
# 876512                           LOCATED EXPLOSIVE DEVICE   Thursday
# 876737                        CARRYING A CONCEALED WEAPON  Wednesday
# 876752     EXHIBITING DEADLY WEAPON IN A THREATING MANNER  Wednesday
# 877024       POSS OF DEADLY WEAPON WITH INTENT TO ASSAULT  Wednesday
# 877205                        CARRYING A CONCEALED WEAPON    Tuesday
# 877206          LOITERING WHILE CARRYING CONCEALED WEAPON    Tuesday
# 877235                        CARRYING A CONCEALED WEAPON    Tuesday
# 877479                             POSS OF LOADED FIREARM    Tuesday
# 877701    POSS OF FIREARM BY CONVICTED FELON/ADDICT/ALIEN     Monday
# 877702     EXHIBITING DEADLY WEAPON IN A THREATING MANNER     Monday
# 877837          LOITERING WHILE CARRYING CONCEALED WEAPON     Monday
# 877843          LOITERING WHILE CARRYING CONCEALED WEAPON     Monday
#
#         PdDistrict           Resolution                         Address  \
# 38         TARAVAL                 NONE       1400 Block of HOLLOWAY AV
# 82        NORTHERN                 NONE           1900 Block of POLK ST
# 363        BAYVIEW                 NONE     900 Block of CONNECTICUT ST
# 717      INGLESIDE                 NONE            0 Block of LELAND AV
# 745        MISSION       ARREST, BOOKED            MISSION ST / 19TH ST
# 746        MISSION       ARREST, BOOKED            MISSION ST / 19TH ST
# 792        BAYVIEW       ARREST, BOOKED         1300 Block of THOMAS AV
# 793        BAYVIEW       ARREST, BOOKED         1300 Block of THOMAS AV
# 796        BAYVIEW       ARREST, BOOKED         1300 Block of THOMAS AV
# 809      INGLESIDE       ARREST, BOOKED            0 Block of SENECA AV
# 810      INGLESIDE       ARREST, BOOKED            0 Block of SENECA AV
# 847        MISSION       ARREST, BOOKED             NATOMA ST / 15TH ST
# 1013       MISSION                 NONE        1000 Block of POTRERO AV
# 1094      SOUTHERN       ARREST, BOOKED         1100 Block of HOWARD ST
# 1121       BAYVIEW                 NONE            0 Block of HUDSON CT
# 1180    TENDERLOIN       ARREST, BOOKED           400 Block of ELLIS ST
# 1183    TENDERLOIN       ARREST, BOOKED           400 Block of ELLIS ST
# 1277       BAYVIEW       ARREST, BOOKED        2000 Block of QUESADA AV
# 1620       CENTRAL       ARREST, BOOKED           1200 Block of HYDE ST
# 1627       BAYVIEW       ARREST, BOOKED           KEITH ST / OAKDALE AV
# 1628       BAYVIEW       ARREST, BOOKED           KEITH ST / OAKDALE AV
# 1630       BAYVIEW                 NONE         SHAFTER AV / INGALLS ST
# 1645       MISSION       ARREST, BOOKED         2400 Block of MARKET ST
# 1772       TARAVAL       ARREST, BOOKED           3900 Block of 19TH AV
# 1919    TENDERLOIN       ARREST, BOOKED      200 Block of MCALLISTER ST
# 2019       TARAVAL       ARREST, BOOKED           1900 Block of 19TH AV
# 2146      RICHMOND      JUVENILE BOOKED            400 Block of 30TH AV
# 2363       MISSION       ARREST, BOOKED        200 Block of SHOTWELL ST
# 2547     INGLESIDE                 NONE            500 Block of YALE ST
# 2572       MISSION       ARREST, BOOKED             15TH ST / JULIAN AV
# ...            ...                  ...                             ...
# 874865   INGLESIDE       ARREST, BOOKED           700 Block of HURON AV
# 874881    RICHMOND       ARREST, BOOKED       400 Block of CROSSOVER DR
# 874888    SOUTHERN       ARREST, BOOKED               0 Block of 6TH ST
# 875000     TARAVAL                 NONE          3100 Block of ULLOA ST
# 875071    SOUTHERN                 NONE         1000 Block of HOWARD ST
# 875077     TARAVAL                 NONE       0 Block of WEST PORTAL AV
# 875096     TARAVAL                 NONE             34TH AV / WAWONA ST
# 875447     MISSION                 NONE            600 Block of CAPP ST
# 875526     TARAVAL                 NONE            400 Block of HEAD ST
# 875594    SOUTHERN        ARREST, CITED              MARKET ST / 7TH ST
# 875892     BAYVIEW                 NONE    WHITNEY YOUNG CR / MABREY CT
# 875901     BAYVIEW       ARREST, BOOKED             3RD ST / OAKDALE AV
# 875957     BAYVIEW       ARREST, BOOKED        1700 Block of QUESADA AV
# 876117        PARK  JUVENILE ADMONISHED          1400 Block of SCOTT ST
# 876197     BAYVIEW                 NONE      2000 Block of BAY SHORE BL
# 876369        PARK                 NONE          1400 Block of SCOTT ST
# 876399    NORTHERN                 NONE           1200 Block of EDDY ST
# 876421     MISSION                 NONE            19TH ST / DOLORES ST
# 876512     MISSION                 NONE            1200 Block of NOE ST
# 876737     MISSION      JUVENILE BOOKED           24TH ST / SHOTWELL ST
# 876752     CENTRAL                 NONE           PACIFIC AV / FRONT ST
# 877024   INGLESIDE       ARREST, BOOKED            0 Block of JUSTIN DR
# 877205  TENDERLOIN       ARREST, BOOKED           100 Block of JONES ST
# 877206  TENDERLOIN       ARREST, BOOKED           100 Block of JONES ST
# 877235     TARAVAL                 NONE      100 Block of FARALLONES ST
# 877479     MISSION            UNFOUNDED  200 Block of SOUTH VAN NESS AV
# 877701     BAYVIEW       ARREST, BOOKED         OAKDALE AV / INGALLS ST
# 877702     BAYVIEW       ARREST, BOOKED         OAKDALE AV / INGALLS ST
# 877837  TENDERLOIN        ARREST, CITED    0 Block of UNITED NATIONS PZ
# 877843  TENDERLOIN        ARREST, CITED    0 Block of UNITED NATIONS PZ
#
#                X         Y
# 38     -1.665884 -0.108243
# 82      0.039189  0.051615
# 363     0.837282 -0.038270
# 717     0.572197 -0.129784
# 745     0.112283 -0.023608
# 746     0.112283 -0.023608
# 792     1.186755 -0.094556
# 793     1.186755 -0.094556
# 796     1.186755 -0.094556
# 809    -0.587915 -0.115985
# 810    -0.587915 -0.115985
# 847     0.564958  0.023865
# 1013    0.529668 -0.031810
# 1094    0.370872  0.011981
# 1121    1.429900 -0.084597
# 1180    0.296740  0.029934
# 1183    0.296740  0.029934
# 1277    0.798971 -0.074037
# 1620    0.166730  0.046223
# 1627    1.185924 -0.084381
# 1628    1.185924 -0.084381
# 1630    1.235239 -0.094465
# 1645   -0.433470 -0.018738
# 1772   -1.627191 -0.118950
# 1919    0.198944  0.021000
# 2019   -1.761887 -0.042871
# 2146   -2.223030  0.021387
# 2363    0.205630 -0.014441
# 2547    0.228801 -0.105835
# 2572    0.051348 -0.009677
# ...          ...       ...
# 874865 -0.916998 -0.130385
# 874881 -1.831051 -0.005134
# 874888  0.434745  0.023189
# 875000 -2.221018 -0.066821
# 875071  0.480547  0.017746
# 875077 -1.444050 -0.067165
# 875096 -2.267969 -0.073843
# 875447  0.158581 -0.032257
# 875526 -1.379194 -0.122114
# 875594  0.332781  0.020699
# 875892  1.213802 -0.077119
# 875901  1.051566 -0.079282
# 875957  1.000898 -0.081206
# 876117 -0.496085  0.026678
# 876197  0.773800 -0.123636
# 876369 -0.496085  0.026678
# 876399 -0.184718  0.023804
# 876421 -0.108851 -0.024497
# 876512 -0.300814 -0.047266
# 876737  0.245203 -0.040665
# 876752  0.755332  0.058627
# 877024  0.002700 -0.080672
# 877205  0.337030  0.025210
# 877206  0.337030  0.025210
# 877235 -1.151794 -0.124536
# 877479  0.161544 -0.004856
# 877701  1.308822 -0.089030
# 877702  1.308822 -0.089030
# 877837  0.273397  0.019532
# 877843  0.273397  0.019532
#
# [8555 rows x 9 columns]

# %% [markdown]
# # Now proceed as before

# %%
def parse_time(x):
    DD=datetime.strptime(x,"%Y-%m-%d %H:%M:%S")
    time=DD.hour#*60+DD.minute
    day=DD.day
    month=DD.month
    year=DD.year
    return time,day,month,year

def get_season(x):
    summer=0
    fall=0
    winter=0
    spring=0
    if (x in [5, 6, 7]):
        summer=1
    if (x in [8, 9, 10]):
        fall=1
    if (x in [11, 0, 1]):
        winter=1
    if (x in [2, 3, 4]):
        spring=1
    return summer, fall, winter, spring

# %%
def parse_data(df,logodds,logoddsPA):
    feature_list=df.columns.tolist()
    if "Descript" in feature_list:
        feature_list.remove("Descript")
    if "Resolution" in feature_list:
        feature_list.remove("Resolution")
    if "Category" in feature_list:
        feature_list.remove("Category")
    if "Id" in feature_list:
        feature_list.remove("Id")
    cleanData=df[feature_list]
    cleanData.index=range(len(df))
    print "Creating address features"
    address_features=cleanData["Address"].apply(lambda x: logodds[x])
    address_features.columns=["logodds"+str(x) for x in range(len(address_features.columns))]
    print "Parsing dates"
    cleanData["Time"], cleanData["Day"], cleanData["Month"], cleanData["Year"]=zip(*cleanData["Dates"].apply(parse_time))
#     dummy_ranks_DAY = pd.get_dummies(cleanData['DayOfWeek'], prefix='DAY')
    days = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
#     cleanData["DayOfWeek"]=cleanData["DayOfWeek"].apply(lambda x: days.index(x)/float(len(days)))
    print "Creating one-hot variables"
    dummy_ranks_PD = pd.get_dummies(cleanData['PdDistrict'], prefix='PD')
    dummy_ranks_DAY = pd.get_dummies(cleanData["DayOfWeek"], prefix='DAY')
    cleanData["IsInterection"]=cleanData["Address"].apply(lambda x: 1 if "/" in x else 0)
    cleanData["logoddsPA"]=cleanData["Address"].apply(lambda x: logoddsPA[x])
    print "droping processed columns"
    cleanData=cleanData.drop("PdDistrict",axis=1)
    cleanData=cleanData.drop("DayOfWeek",axis=1)
    cleanData=cleanData.drop("Address",axis=1)
    cleanData=cleanData.drop("Dates",axis=1)
    feature_list=cleanData.columns.tolist()
    print "joining one-hot features"
    features = cleanData[feature_list].join(dummy_ranks_PD.ix[:,:]).join(dummy_ranks_DAY.ix[:,:]).join(address_features.ix[:,:])
    print "creating new features"
    features["IsDup"]=pd.Series(features.duplicated()|features.duplicated(take_last=True)).apply(int)
    features["Awake"]=features["Time"].apply(lambda x: 1 if (x==0 or (x>=8 and x<=23)) else 0)
    features["Summer"], features["Fall"], features["Winter"], features["Spring"]=zip(*features["Month"].apply(get_season))
    if "Category" in df.columns:
        labels = df["Category"].astype('category')
#         label_names=labels.unique()
#         labels=labels.cat.rename_categories(range(len(label_names)))
    else:
        labels=None
    return features,labels

# %% [markdown]
# This part is slower than it needs to be.

# %%
addresses=sorted(trainDF["Address"].unique())
categories=sorted(trainDF["Category"].unique())
C_counts=trainDF.groupby(["Category"]).size()
A_C_counts=trainDF.groupby(["Address","Category"]).size()
A_counts=trainDF.groupby(["Address"]).size()
logodds={}
logoddsPA={}
MIN_CAT_COUNTS=2
default_logodds=np.log(C_counts/len(trainDF))-np.log(1.0-C_counts/float(len(trainDF)))
for addr in addresses:
    PA=A_counts[addr]/float(len(trainDF))
    logoddsPA[addr]=np.log(PA)-np.log(1.-PA)
    logodds[addr]=deepcopy(default_logodds)
    for cat in A_C_counts[addr].keys():
        if (A_C_counts[addr][cat]>MIN_CAT_COUNTS) and A_C_counts[addr][cat]<A_counts[addr]:
            PA=A_C_counts[addr][cat]/float(A_counts[addr])
            logodds[addr][categories.index(cat)]=np.log(PA)-np.log(1.0-PA)
    logodds[addr]=pd.Series(logodds[addr])
    logodds[addr].index=range(len(categories))

# %%
len(trainDF)
# Out:
# 877982

# %%
features, labels=parse_data(trainDF,logodds,logoddsPA)
# Out:
# Creating address features
# Parsing dates
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Creating one-hot variables
# droping processed columns
# joining one-hot features
# creating new features
# /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/ipykernel/__main__.py:35: FutureWarning: the take_last=True keyword is deprecated, use keep='last' instead

# %%
print features.columns.tolist()
print len(features.columns)
# Out:
# ['X', 'Y', 'Time', 'Day', 'Month', 'Year', 'IsInterection', 'logoddsPA', 'PD_BAYVIEW', 'PD_CENTRAL', 'PD_INGLESIDE', 'PD_MISSION', 'PD_NORTHERN', 'PD_PARK', 'PD_RICHMOND', 'PD_SOUTHERN', 'PD_TARAVAL', 'PD_TENDERLOIN', 'DAY_Friday', 'DAY_Monday', 'DAY_Saturday', 'DAY_Sunday', 'DAY_Thursday', 'DAY_Tuesday', 'DAY_Wednesday', 'logodds0', 'logodds1', 'logodds2', 'logodds3', 'logodds4', 'logodds5', 'logodds6', 'logodds7', 'logodds8', 'logodds9', 'logodds10', 'logodds11', 'logodds12', 'logodds13', 'logodds14', 'logodds15', 'logodds16', 'logodds17', 'logodds18', 'logodds19', 'logodds20', 'logodds21', 'logodds22', 'logodds23', 'logodds24', 'logodds25', 'logodds26', 'logodds27', 'logodds28', 'logodds29', 'logodds30', 'logodds31', 'logodds32', 'logodds33', 'logodds34', 'logodds35', 'logodds36', 'logodds37', 'logodds38', 'IsDup', 'Awake', 'Summer', 'Fall', 'Winter', 'Spring']
# 70

# %%
# num_feature_list=["Time","Day","Month","Year","DayOfWeek"]
collist=features.columns.tolist()
scaler = preprocessing.StandardScaler()
scaler.fit(features)
features[collist]=scaler.transform(features)

# %%
# Out:
# ['X',
#  'Y',
#  'Time',
#  'Day',
#  'Month',
#  'Year',
#  'IsInterection',
#  'logoddsPA',
#  'PD_BAYVIEW',
#  'PD_CENTRAL',
#  'PD_INGLESIDE',
#  'PD_MISSION',
#  'PD_NORTHERN',
#  'PD_PARK',
#  'PD_RICHMOND',
#  'PD_SOUTHERN',
#  'PD_TARAVAL',
#  'PD_TENDERLOIN',
#  'DAY_Friday',
#  'DAY_Monday',
#  'DAY_Saturday',
#  'DAY_Sunday',
#  'DAY_Thursday',
#  'DAY_Tuesday',
#  'DAY_Wednesday',
#  'logodds0',
#  'logodds1',
#  'logodds2',
#  'logodds3',
#  'logodds4',
#  'logodds5',
#  'logodds6',
#  'logodds7',
#  'logodds8',
#  'logodds9',
#  'logodds10',
#  'logodds11',
#  'logodds12',
#  'logodds13',
#  'logodds14',
#  'logodds15',
#  'logodds16',
#  'logodds17',
#  'logodds18',
#  'logodds19',
#  'logodds20',
#  'logodds21',
#  'logodds22',
#  'logodds23',
#  'logodds24',
#  'logodds25',
#  'logodds26',
#  'logodds27',
#  'logodds28',
#  'logodds29',
#  'logodds30',
#  'logodds31',
#  'logodds32',
#  'logodds33',
#  'logodds34',
#  'logodds35',
#  'logodds36',
#  'logodds37',
#  'logodds38',
#  'IsDup',
#  'Awake',
#  'Summer',
#  'Fall',
#  'Winter',
#  'Spring']

# %%
new_PCA=PCA(n_components=60)
new_PCA.fit(features)
plt.plot(new_PCA.explained_variance_ratio_)
plt.yscale('log')
plt.title("PCA explained ratio of features")
print new_PCA.explained_variance_ratio_
# Out:
# [ 0.07714363  0.06267647  0.04861061  0.04300871  0.03340587  0.03085896
#   0.02834616  0.02731142  0.02509795  0.02393235  0.02272111  0.02029053
#   0.02000664  0.019452    0.01918369  0.01820193  0.01729548  0.01724542
#   0.01715838  0.01714426  0.01703779  0.01695665  0.01668107  0.01651773
#   0.01626539  0.01588035  0.01489293  0.01472615  0.01422875  0.01412131
#   0.0136947   0.01330571  0.01234474  0.01181851  0.01158515  0.01126484
#   0.01104143  0.0105683   0.01032344  0.00943963  0.00903894  0.00838257
#   0.00819149  0.00795652  0.0074206   0.00726109  0.00707183  0.00675531
#   0.0067189   0.00646287  0.00634686  0.00612685  0.0060737   0.00556134
#   0.00526841  0.00516993  0.0048638   0.00452517  0.00417899  0.00407036]

# %%
plt.plot(new_PCA.explained_variance_ratio_.cumsum())
plt.title("cumsum of PCA explained ratio")

# %% [markdown]
# PCA is interesting, here to play with it more

# %%
# features=new_PCA.transform(features)
# features=pd.DataFrame(features)

# %%
sss = StratifiedShuffleSplit(labels, train_size=0.5)
for train_index, test_index in sss:
    features_train,features_test=features.iloc[train_index],features.iloc[test_index]
    labels_train,labels_test=labels[train_index],labels[test_index]
features_test.index=range(len(features_test))
features_train.index=range(len(features_train))
labels_train.index=range(len(labels_train))
labels_test.index=range(len(labels_test))
features.index=range(len(features))
labels.index=range(len(labels))

# %%
def build_and_fit_model(X_train,y_train,X_test=None,y_test=None,hn=32,dp=0.5,layers=1,epochs=1,batches=64,verbose=0):
    input_dim=X_train.shape[1]
    output_dim=len(labels_train.unique())
    Y_train=np_utils.to_categorical(y_train.cat.rename_categories(range(len(y_train.unique()))))
#     print output_dim
    model = Sequential()
    model.add(Dense(input_dim, hn, init='glorot_uniform'))
    model.add(PReLU((hn,)))
    model.add(Dropout(dp))

    for i in range(layers):
      model.add(Dense(hn, hn, init='glorot_uniform'))
      model.add(PReLU((hn,)))
      model.add(BatchNormalization((hn,)))
      model.add(Dropout(dp))

    model.add(Dense(hn, output_dim, init='glorot_uniform'))
    model.add(Activation('softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam')
    
    if X_test is not None:
        Y_test=np_utils.to_categorical(y_test.cat.rename_categories(range(len(y_test.unique()))))
        fitting=model.fit(X_train, Y_train, nb_epoch=epochs, batch_size=batches,verbose=verbose,validation_data=(X_test,Y_test))
        test_score = log_loss(y_test, model.predict_proba(X_test,verbose=0))
    else:
        model.fit(X_train, Y_train, nb_epoch=epochs, batch_size=batches,verbose=verbose)
        fitting=0
        test_score = 0
    return test_score, fitting, model

# %%
len(features.columns)
# Out:
# 70

# %%
N_EPOCHS=20
N_HN=128
N_LAYERS=1
DP=0.5

# %%
score, fitting, model = build_and_fit_model(features_train.as_matrix(),labels_train,X_test=features_test.as_matrix(),y_test=labels_test,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
# Out:
# Train on 438991 samples, validate on 438988 samples
# Epoch 0
# 33s - loss: 2.3470 - val_loss: 2.2305
# Epoch 1
# 34s - loss: 2.2776 - val_loss: 2.2194
# Epoch 2
# 33s - loss: 2.2687 - val_loss: 2.2133
# Epoch 3
# 40s - loss: 2.2616 - val_loss: 2.2096
# Epoch 4
# 37s - loss: 2.2581 - val_loss: 2.2071
# Epoch 5
# 40s - loss: 2.2553 - val_loss: 2.2043
# Epoch 6
# 40s - loss: 2.2529 - val_loss: 2.2023
# Epoch 7
# 38s - loss: 2.2499 - val_loss: 2.2019
# Epoch 8
# 35s - loss: 2.2488 - val_loss: 2.2011
# Epoch 9
# 35s - loss: 2.2479 - val_loss: 2.1988
# Epoch 10
# 35s - loss: 2.2451 - val_loss: 2.1975
# Epoch 11
# 39s - loss: 2.2431 - val_loss: 2.1956
# Epoch 12
# 36s - loss: 2.2425 - val_loss: 2.1955
# Epoch 13
# 35s - loss: 2.2426 - val_loss: 2.1938
# Epoch 14
# 37s - loss: 2.2401 - val_loss: 2.1952
# Epoch 15
# 36s - loss: 2.2400 - val_loss: 2.1926
# Epoch 16
# 36s - loss: 2.2392 - val_loss: 2.1925
# Epoch 17
# 39s - loss: 2.2382 - val_loss: 2.1909
# Epoch 18
# 35s - loss: 2.2384 - val_loss: 2.1913
# Epoch 19
# 38s - loss: 2.2370 - val_loss: 2.1907

# %%
print "all", log_loss(labels, model.predict_proba(features.as_matrix(),verbose=0))
print "train", log_loss(labels_train, model.predict_proba(features_train.as_matrix(),verbose=0))
print "test", log_loss(labels_test, model.predict_proba(features_test.as_matrix(),verbose=0))
# Out:
#  all 2.20831236726
# train 2.18018233454
# test 2.18310275473

# %%
plt.plot(fitting.history['val_loss'],label="validation")
plt.plot(fitting.history['loss'],label="train")
# plt.xscale('log')
plt.legend()

# %% [markdown]
# Now train the final model

# %%
score, fitting, model = build_and_fit_model(features.as_matrix(),labels,hn=N_HN,layers=N_LAYERS,epochs=N_EPOCHS,verbose=2,dp=DP)
# Out:
# Epoch 0
# 55s - loss: 2.3152
# Epoch 1
# 52s - loss: 2.2672
# Epoch 2
# 53s - loss: 2.2591
# Epoch 3
# 54s - loss: 2.2545
# Epoch 4
# 55s - loss: 2.2507
# Epoch 5
# 56s - loss: 2.2490
# Epoch 6
# 56s - loss: 2.2468
# Epoch 7
# 58s - loss: 2.2447
# Epoch 8
# 69s - loss: 2.2430
# Epoch 9
# 63s - loss: 2.2424
# Epoch 10
# 60s - loss: 2.2409
# Epoch 11
# 58s - loss: 2.2414
# Epoch 12
# 57s - loss: 2.2401
# Epoch 13
# 58s - loss: 2.2395
# Epoch 14
# 60s - loss: 2.2388
# Epoch 15
# 67s - loss: 2.2378
# Epoch 16
# 58s - loss: 2.2379
# Epoch 17
# 64s - loss: 2.2373
# Epoch 18
# 58s - loss: 2.2367
# Epoch 19
# 63s - loss: 2.2370

# %%
print "all", log_loss(labels, model.predict_proba(features.as_matrix(),verbose=0))
print "train", log_loss(labels_train, model.predict_proba(features_train.as_matrix(),verbose=0))
print "test", log_loss(labels_test, model.predict_proba(features_test.as_matrix(),verbose=0))
# Out:
# all 2.20350119735
# train 2.17428331289
# test 2.17730264602

# %%
testDF=pd.read_csv("../../test.csv")
testDF[["X","Y"]]=xy_scaler.transform(testDF[["X","Y"]])
#set outliers to 0
testDF["X"]=testDF["X"].apply(lambda x: 0 if abs(x)>5 else x)
testDF["Y"]=testDF["Y"].apply(lambda y: 0 if abs(y)>5 else y)

# %%
new_addresses=sorted(testDF["Address"].unique())
new_A_counts=testDF.groupby("Address").size()
only_new=set(new_addresses+addresses)-set(addresses)
only_old=set(new_addresses+addresses)-set(new_addresses)
in_both=set(new_addresses).intersection(addresses)
for addr in only_new:
    PA=new_A_counts[addr]/float(len(testDF)+len(trainDF))
    logoddsPA[addr]=np.log(PA)-np.log(1.-PA)
    logodds[addr]=deepcopy(default_logodds)
    logodds[addr].index=range(len(categories))
for addr in in_both:
    PA=(A_counts[addr]+new_A_counts[addr])/float(len(testDF)+len(trainDF))
    logoddsPA[addr]=np.log(PA)-np.log(1.-PA)

# %%
features_sub, _=parse_data(testDF,logodds,logoddsPA)
# scaler.fit(features_test)
# Out:
# Creating address features
# Parsing dates
# Creating one-hot variables
# droping processed columns
# joining one-hot features
# creating new features

# %%
collist=features_sub.columns.tolist()
print collist
# Out:
# ['X', 'Y', 'Time', 'Day', 'Month', 'Year', 'IsInterection', 'logoddsPA', 'PD_BAYVIEW', 'PD_CENTRAL', 'PD_INGLESIDE', 'PD_MISSION', 'PD_NORTHERN', 'PD_PARK', 'PD_RICHMOND', 'PD_SOUTHERN', 'PD_TARAVAL', 'PD_TENDERLOIN', 'DAY_Friday', 'DAY_Monday', 'DAY_Saturday', 'DAY_Sunday', 'DAY_Thursday', 'DAY_Tuesday', 'DAY_Wednesday', 'logodds0', 'logodds1', 'logodds2', 'logodds3', 'logodds4', 'logodds5', 'logodds6', 'logodds7', 'logodds8', 'logodds9', 'logodds10', 'logodds11', 'logodds12', 'logodds13', 'logodds14', 'logodds15', 'logodds16', 'logodds17', 'logodds18', 'logodds19', 'logodds20', 'logodds21', 'logodds22', 'logodds23', 'logodds24', 'logodds25', 'logodds26', 'logodds27', 'logodds28', 'logodds29', 'logodds30', 'logodds31', 'logodds32', 'logodds33', 'logodds34', 'logodds35', 'logodds36', 'logodds37', 'logodds38', 'IsDup', 'Awake', 'Summer', 'Fall', 'Winter', 'Spring']

# %%
features_sub[collist]=scaler.transform(features_sub[collist])

# %%
predDF=pd.DataFrame(model.predict_proba(features_sub.as_matrix(),verbose=0),columns=sorted(labels.unique()))

# %%
predDF.head()
# Out:
#       ARSON   ASSAULT  BAD CHECKS   BRIBERY  BURGLARY  DISORDERLY CONDUCT  \
# 0  0.004689  0.098936    0.000187  0.000129  0.062209            0.003510
# 1  0.002153  0.083348    0.000027  0.000086  0.000938            0.001392
# 2  0.002262  0.028248    0.000174  0.000017  0.259758            0.001492
# 3  0.000961  0.217098    0.000141  0.003030  0.009785            0.007843
# 4  0.000961  0.217098    0.000141  0.003030  0.009785            0.007843
#
#    DRIVING UNDER THE INFLUENCE  DRUG/NARCOTIC  DRUNKENNESS  EMBEZZLEMENT  \
# 0                     0.001250       0.021802     0.001641      0.000773
# 1                     0.005868       0.050063     0.002007      0.000026
# 2                     0.001225       0.003016     0.000441      0.001183
# 3                     0.002701       0.125863     0.024627      0.000194
# 4                     0.002701       0.125863     0.024627      0.000194
#
#       ...       SEX OFFENSES NON FORCIBLE  STOLEN PROPERTY   SUICIDE  \
# 0     ...                        0.000538         0.001224  0.001094
# 1     ...                        0.000030         0.001069  0.000023
# 2     ...                        0.000039         0.000734  0.000773
# 3     ...                        0.000126         0.012048  0.000485
# 4     ...                        0.000126         0.012048  0.000485
#
#    SUSPICIOUS OCC          TREA  TRESPASS  VANDALISM  VEHICLE THEFT  WARRANTS  \
# 0        0.046618  2.101852e-06  0.006748   0.094425       0.123388  0.030323
# 1        0.021384  3.896940e-08  0.000725   0.032963       0.063096  0.070983
# 2        0.027552  1.380572e-07  0.004622   0.078929       0.179449  0.006987
# 3        0.025891  5.712422e-07  0.007958   0.032432       0.005983  0.082637
# 4        0.025891  5.712422e-07  0.007958   0.032432       0.005983  0.082637
#
#    WEAPON LAWS
# 0     0.007257
# 1     0.019628
# 2     0.001500
# 3     0.058221
# 4     0.058221
#
# [5 rows x 39 columns]

# %%
predDF.to_csv("crimeSF_NN_logodds.csv",index_label="Id",na_rep="0")
